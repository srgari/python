# %%
import matplotlib.pyplot as plt, numpy as np

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

#right wing
a=[x**2 for x in np.arange(-1,1.1,0.1)]
b=np.arange(-1,1.1,0.1)

#left wing
c=[-x**2+5 for x in np.arange(-1,1.1,0.1)]
d=np.arange(-1,1.1,0.1)

#lowering upper left
e=np.linspace(1,2,20)
f=[x**2+0.75 for x in np.linspace(-0.5,0.7,20)]

#lowering upper left
g=np.linspace(3,4,20)
h=[x**2+0.75 for x in np.linspace(-0.7,0.5,20)]

#ears
i=[2,2.1]
j=[(-0.7)**2 +0.75,1]
k=[2.9,3]
l=[1,(-0.7)**2 +0.75]

#head
m=np.linspace(2.1,2.9,10)
n=[-x**2+1.04 for x in np.linspace(-0.2,0.2,10)]

#tail
o=np.linspace(1,2.5,10)
p=[-x**2-0.64 for x in np.linspace(-0.6,0.6,10)]
q=np.linspace(2.5,4,10)
r=[-x**2-0.64 for x in np.linspace(-0.6,0.6,10)]


letters = 'abcdefghijklmnopqr'

ax.fill_between(a,b)

for x in range(0,len(letters),2):
    ax.fill_between(globals()[letters[x]],globals()[letters[x+1]], color='k')
